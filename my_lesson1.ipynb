# %% [markdown]
# # Thuc hanh Tri tue nhan tao Buoi 1
#
# ## Noi dung thuc hanh

# %% [markdown]
# ### In chu ra man hinh

# %%
# lenh 1 - xuat chu
print("Hello, Python World!")
# Out:
# Hello, Python World!

# %% [markdown]
# ### Chay tap tin python

# %%
# !python ex0_hello_world.py
# Out:
# Hello, Python World!

# %%
# %run ex0_hello_world.py
# Out:
# Hello, Python World!

# %%
# %run ex1_calc.py
# Out:
# Calculator Basic
# Moi ban nhap so a:  1
# Moi ban nhap so b:  2
# c = 1 + 2 = 3

# %%
# %run ex3_circle.py
# Out:
# Moi ban nhap ban kinh:  2
# Chu vi: 12.566371
# Dien tich: 25.132741

# %% [markdown]
# # Ket thuc
